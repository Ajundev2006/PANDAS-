# %% [markdown]
# ### section A

# %%
import pandas as pd

# %%
emp=pd.read_csv(r"C:\Users\admin\Documents\Data Analytics\ajun\files\employee_data.csv")

# %%
emp
# Out:
#     ID          Name Department      City        Job Role   Salary  Exp_Yrs  \
# 0    1    Arun Kumar      Sales   Calicut       Executive  28000.0        3
# 1    2    Priya Nair         IT     Kochi       Developer  45000.0        5
# 2    3   Rahul Menon         HR   Calicut         Manager  38000.0        7
# 3    4     Sneha Das      Sales  Thrissur       Executive  29000.0        2
# 4    5       Vijay S         IT     Kochi       Developer  47000.0        6
# ..  ..           ...        ...       ...             ...      ...      ...
# 58  59  Joseph Kumar    Finance  Thrissur  Senior Analyst  38500.0        7
# 59  60   Sreeja Devi    Finance   Calicut  Senior Analyst  48000.0       11
# 60  61    Priya Nair         IT     Kochi       Developer  45000.0        5
# 61  62       Anoop M         IT   Calicut       Developer  43000.0        5
# 62  63   Jishnu Devi         HR  Thrissur       Recruiter  26000.0       10
#
#     Rating
# 0      4.2
# 1      4.7
# 2      NaN
# ...

# %%
emp.head(5)
# Out:
#    ID         Name Department      City   Job Role   Salary  Exp_Yrs  Rating
# 0   1   Arun Kumar      Sales   Calicut  Executive  28000.0        3     4.2
# 1   2   Priya Nair         IT     Kochi  Developer  45000.0        5     4.7
# 2   3  Rahul Menon         HR   Calicut    Manager  38000.0        7     NaN
# 3   4    Sneha Das      Sales  Thrissur  Executive  29000.0        2     3.9
# 4   5      Vijay S         IT     Kochi  Developer  47000.0        6     4.5

# %%
emp.shape
# Out:
# (63, 8)

# %%
emp.columns
# Out:
# Index(['ID', 'Name', 'Department', 'City', 'Job Role', 'Salary', 'Exp_Yrs',
#        'Rating'],
#       dtype='object')

# %%
emp.dtypes
# Out:
# ID              int64
# Name           object
# Department     object
# City           object
# Job Role       object
# Salary        float64
# Exp_Yrs         int64
# Rating        float64
# dtype: object

# %%
emp.columns.value_counts()
# Out:
# ID            1
# Name          1
# Department    1
# City          1
# Job Role      1
# Salary        1
# Exp_Yrs       1
# Rating        1
# Name: count, dtype: int64

# %%
emp.isnull().sum()
# Out:
# ID            0
# Name          5
# Department    0
# City          6
# Job Role      0
# Salary        1
# Exp_Yrs       0
# Rating        5
# dtype: int64

# %%
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63 entries, 0 to 62
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          63 non-null     int64
#  1   Name        58 non-null     object
#  2   Department  63 non-null     object
#  3   City        57 non-null     object
#  4   Job Role    63 non-null     object
#  5   Salary      62 non-null     float64
#  6   Exp_Yrs     63 non-null     int64
#  7   Rating      58 non-null     float64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 4.1+ KB

# %%
emp.isnull().sum()
# Out:
# ID            0
# Name          5
# Department    0
# City          6
# Job Role      0
# Salary        1
# Exp_Yrs       0
# Rating        5
# dtype: int64

# %%
emp.describe()
# Out:
#               ID        Salary    Exp_Yrs     Rating
# count  63.000000     62.000000  63.000000  58.000000
# mean   32.000000  38822.580645   6.063492   4.194828
# std    18.330303  12657.239480   3.267005   0.455925
# min     1.000000  25000.000000   1.000000   3.400000
# 25%    16.500000  28000.000000   3.000000   3.800000
# 50%    32.000000  34000.000000   6.000000   4.200000
# 75%    47.500000  46500.000000   9.000000   4.600000
# max    63.000000  65500.000000  12.000000   4.900000

# %%
emp["Salary"].mean()
# Out:
# np.float64(38822.58064516129)

# %%
emp.size
# Out:
# 504

# %%
emp["Department"].unique()
# Out:
# array(['Sales', 'IT', 'HR', 'Finance'], dtype=object)

# %%
emp["Department"].nunique()
# Out:
# 4

# %%
emp["Department"].value_counts().sort_values(ascending=False)
# Out:
# Department
# Sales      19
# IT         19
# HR         16
# Finance     9
# Name: count, dtype: int64

# %%
emp["City"].value_counts()
# Out:
# City
# Calicut     18
# Kochi       15
# Thrissur    12
# Palakkad     8
# Kannur       4
# Name: count, dtype: int64

# %%
emp["City"].unique()
# Out:
# array(['Calicut', 'Kochi', 'Thrissur', nan, 'Palakkad', 'Kannur'],
#       dtype=object)

# %%
emp["Job Role"].unique()
# Out:
# array(['Executive', 'Developer', 'Manager', 'Analyst', 'Lead',
#        'Senior Analyst', 'Senior Executive', 'Recruiter', 'QA Engineer',
#        'Senior Developer'], dtype=object)

# %%
emp["Job Role"].nunique()
# Out:
# 10

# %%
emp[["Name","Department","Salary"]]
# Out:
#             Name Department   Salary
# 0     Arun Kumar      Sales  28000.0
# 1     Priya Nair         IT  45000.0
# 2    Rahul Menon         HR  38000.0
# 3      Sneha Das      Sales  29000.0
# 4        Vijay S         IT  47000.0
# ..           ...        ...      ...
# 58  Joseph Kumar    Finance  38500.0
# 59   Sreeja Devi    Finance  48000.0
# 60    Priya Nair         IT  45000.0
# 61       Anoop M         IT  43000.0
# 62   Jishnu Devi         HR  26000.0
#
# [63 rows x 3 columns]

# %% [markdown]
# ### Section B

# %%
emp.isnull().sum()
# Out:
# ID            0
# Name          5
# Department    0
# City          6
# Job Role      0
# Salary        1
# Exp_Yrs       0
# Rating        5
# dtype: int64

# %%
emp.duplicated().sum()
# Out:
# np.int64(0)

# %%
emp.drop_duplicates()
# Out:
#     ID          Name Department      City        Job Role   Salary  Exp_Yrs  \
# 0    1    Arun Kumar      Sales   Calicut       Executive  28000.0        3
# 1    2    Priya Nair         IT     Kochi       Developer  45000.0        5
# 2    3   Rahul Menon         HR   Calicut         Manager  38000.0        7
# 3    4     Sneha Das      Sales  Thrissur       Executive  29000.0        2
# 4    5       Vijay S         IT     Kochi       Developer  47000.0        6
# ..  ..           ...        ...       ...             ...      ...      ...
# 58  59  Joseph Kumar    Finance  Thrissur  Senior Analyst  38500.0        7
# 59  60   Sreeja Devi    Finance   Calicut  Senior Analyst  48000.0       11
# 60  61    Priya Nair         IT     Kochi       Developer  45000.0        5
# 61  62       Anoop M         IT   Calicut       Developer  43000.0        5
# 62  63   Jishnu Devi         HR  Thrissur       Recruiter  26000.0       10
#
#     Rating
# 0      4.2
# 1      4.7
# 2      NaN
# ...

# %%
emp.shape
# Out:
# (63, 8)

# %%
emp.drop("ID",axis=1)
# Out:
#             Name Department      City        Job Role   Salary  Exp_Yrs  \
# 0     Arun Kumar      Sales   Calicut       Executive  28000.0        3
# 1     Priya Nair         IT     Kochi       Developer  45000.0        5
# 2    Rahul Menon         HR   Calicut         Manager  38000.0        7
# 3      Sneha Das      Sales  Thrissur       Executive  29000.0        2
# 4        Vijay S         IT     Kochi       Developer  47000.0        6
# ..           ...        ...       ...             ...      ...      ...
# 58  Joseph Kumar    Finance  Thrissur  Senior Analyst  38500.0        7
# 59   Sreeja Devi    Finance   Calicut  Senior Analyst  48000.0       11
# 60    Priya Nair         IT     Kochi       Developer  45000.0        5
# 61       Anoop M         IT   Calicut       Developer  43000.0        5
# 62   Jishnu Devi         HR  Thrissur       Recruiter  26000.0       10
#
#     Rating
# 0      4.2
# 1      4.7
# 2      NaN
# 3      3.9
# 4      4.5
# ..     ...
# 58     4.6
# ...

# %%
emp.dropna()
# Out:
#     ID                Name Department      City          Job Role   Salary  \
# 0    1          Arun Kumar      Sales   Calicut         Executive  28000.0
# 1    2          Priya Nair         IT     Kochi         Developer  45000.0
# 3    4           Sneha Das      Sales  Thrissur         Executive  29000.0
# 4    5             Vijay S         IT     Kochi         Developer  47000.0
# 7    8          Arun Kumar      Sales   Calicut         Executive  28000.0
# 8    9             Divya R         HR  Thrissur         Executive  26000.0
# 10  11             Anoop M         IT   Calicut         Developer  43000.0
# 12  13             Rajan T    Finance   Calicut    Senior Analyst  41000.0
# 15  16            Sreeja V         HR   Calicut         Executive  25000.0
# 17  18           Lakshmi G      Sales  Thrissur         Executive  27000.0
# 18  19          Arun Kumar      Sales   Calicut         Executive  28000.0
# ...

# %%
emp.shape
# Out:
# (63, 8)

# %%
emp.dropna(subset=["Salary"],inplace=True)

# %%
emp.isnull().sum()
# Out:
# ID            0
# Name          5
# Department    0
# City          6
# Job Role      0
# Salary        0
# Exp_Yrs       0
# Rating        5
# dtype: int64

# %%
emp[emp["Department"]=="IT"]
# Out:
#     ID          Name Department      City          Job Role   Salary  Exp_Yrs  \
# 1    2    Priya Nair         IT     Kochi         Developer  45000.0        5
# 4    5       Vijay S         IT     Kochi         Developer  47000.0        6
# 6    7  Meera Pillai         IT       NaN              Lead  62000.0        9
# 10  11       Anoop M         IT   Calicut         Developer  43000.0        5
# 13  14           NaN         IT  Thrissur         Developer  44000.0        5
# 14  15  Meera Pillai         IT       NaN              Lead  62000.0        9
# 19  20      Jishnu C         IT     Kochi              Lead  65000.0       11
# 26  27           NaN         IT     Kochi         Developer  65500.0        6
# 27  28     Pradeep G         IT    Kannur              Lead  48000.0        3
# 34  35      Vishnu G         IT  Thrissur       QA Engineer  56500.0        8
# 35  36           NaN         IT   Calicut              Lead  42000.0        1
# ...

# %%
emp[["Name","Job Role"]]
# Out:
#             Name        Job Role
# 0     Arun Kumar       Executive
# 1     Priya Nair       Developer
# 2    Rahul Menon         Manager
# 3      Sneha Das       Executive
# 4        Vijay S       Developer
# ..           ...             ...
# 58  Joseph Kumar  Senior Analyst
# 59   Sreeja Devi  Senior Analyst
# 60    Priya Nair       Developer
# 61       Anoop M       Developer
# 62   Jishnu Devi       Recruiter
#
# [62 rows x 2 columns]

# %%
emp.isnull().sum()
# Out:
# ID            0
# Name          5
# Department    0
# City          6
# Job Role      0
# Salary        0
# Exp_Yrs       0
# Rating        5
# dtype: int64

# %%
emp.drop_duplicates(inplace=True)

# %%
emp.shape
# Out:
# (62, 8)

# %%
emp.drop("ID",axis=1)
# Out:
#             Name Department      City        Job Role   Salary  Exp_Yrs  \
# 0     Arun Kumar      Sales   Calicut       Executive  28000.0        3
# 1     Priya Nair         IT     Kochi       Developer  45000.0        5
# 2    Rahul Menon         HR   Calicut         Manager  38000.0        7
# 3      Sneha Das      Sales  Thrissur       Executive  29000.0        2
# 4        Vijay S         IT     Kochi       Developer  47000.0        6
# ..           ...        ...       ...             ...      ...      ...
# 58  Joseph Kumar    Finance  Thrissur  Senior Analyst  38500.0        7
# 59   Sreeja Devi    Finance   Calicut  Senior Analyst  48000.0       11
# 60    Priya Nair         IT     Kochi       Developer  45000.0        5
# 61       Anoop M         IT   Calicut       Developer  43000.0        5
# 62   Jishnu Devi         HR  Thrissur       Recruiter  26000.0       10
#
#     Rating
# 0      4.2
# 1      4.7
# 2      NaN
# 3      3.9
# 4      4.5
# ..     ...
# 58     4.6
# ...

# %%
emp.dropna()
# Out:
#     ID                Name Department      City          Job Role   Salary  \
# 0    1          Arun Kumar      Sales   Calicut         Executive  28000.0
# 1    2          Priya Nair         IT     Kochi         Developer  45000.0
# 3    4           Sneha Das      Sales  Thrissur         Executive  29000.0
# 4    5             Vijay S         IT     Kochi         Developer  47000.0
# 7    8          Arun Kumar      Sales   Calicut         Executive  28000.0
# 8    9             Divya R         HR  Thrissur         Executive  26000.0
# 10  11             Anoop M         IT   Calicut         Developer  43000.0
# 12  13             Rajan T    Finance   Calicut    Senior Analyst  41000.0
# 15  16            Sreeja V         HR   Calicut         Executive  25000.0
# 17  18           Lakshmi G      Sales  Thrissur         Executive  27000.0
# 18  19          Arun Kumar      Sales   Calicut         Executive  28000.0
# ...

# %%
emp["Department"].value_counts()
# Out:
# Department
# IT         19
# Sales      18
# HR         16
# Finance     9
# Name: count, dtype: int64

# %%
emp["City"].unique()
# Out:
# array(['Calicut', 'Kochi', 'Thrissur', nan, 'Palakkad', 'Kannur'],
#       dtype=object)

# %%
emp["Exp_Yrs"].mean()
# Out:
# np.float64(6.032258064516129)
